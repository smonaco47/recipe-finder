# %%
import pandas as pd
import seaborn as sbn

# %%
df = pd.read_csv('../data/RAW_recipes.csv')#, index_col='id'

# %%
df.count()
# Out:
# name              231636
# id                231637
# minutes           231637
# contributor_id    231637
# submitted         231637
# tags              231637
# nutrition         231637
# n_steps           231637
# steps             231637
# description       226658
# ingredients       231637
# n_ingredients     231637
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 231637 entries, 0 to 231636
# Data columns (total 12 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   name            231636 non-null  object
#  1   id              231637 non-null  int64
#  2   minutes         231637 non-null  int64
#  3   contributor_id  231637 non-null  int64
#  4   submitted       231637 non-null  object
#  5   tags            231637 non-null  object
#  6   nutrition       231637 non-null  object
#  7   n_steps         231637 non-null  int64
#  8   steps           231637 non-null  object
#  9   description     226658 non-null  object
#  10  ingredients     231637 non-null  object
#  11  n_ingredients   231637 non-null  int64
# dtypes: int64(5), object(7)
# memory usage: 21.2+ MB

# %%
df.head()
# Out:
#                                          name      id  minutes  \
# 0  arriba   baked winter squash mexican style  137739       55
# 1            a bit different  breakfast pizza   31490       30
# 2                   all in the kitchen  chili  112140      130
# 3                          alouette  potatoes   59389       45
# 4          amish  tomato ketchup  for canning   44061      190
#
#    contributor_id   submitted  \
# 0           47892  2005-09-16
# 1           26278  2002-06-17
# 2          196586  2005-02-25
# 3           68585  2003-04-14
# 4           41706  2002-10-25
#
#                                                 tags  \
# 0  ['60-minutes-or-less', 'time-to-make', 'course...
# 1  ['30-minutes-or-less', 'time-to-make', 'course...
# 2  ['time-to-make', 'course', 'preparation', 'mai...
# 3  ['60-minutes-or-less', 'time-to-make', 'course...
# 4  ['weeknight', 'time-to-make', 'course', 'main-...
#
#                                     nutrition  n_steps  \
# 0       [51.5, 0.0, 13.0, 0.0, 2.0, 0.0, 4.0]       11
# 1   [173.4, 18.0, 0.0, 17.0, 22.0, 35.0, 1.0]        9
# 2  [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 3   [368.1, 17.0, 10.0, 2.0, 14.0, 8.0, 20.0]       11
# 4   [352.9, 1.0, 337.0, 23.0, 3.0, 0.0, 28.0]        5
#
#                                                steps  \
# 0  ['make a choice and proceed with recipe', 'dep...
# 1  ['preheat oven to 425 degrees f', 'press dough...
# 2  ['brown ground beef in large pot', 'add choppe...
# 3  ['place potatoes in a large pot of lightly sal...
# 4  ['mix all ingredients& boil for 2 1 / 2 hours ...
#
#                                          description  \
# 0  autumn is my favorite time of year to cook! th...
# 1  this recipe calls for the crust to be prebaked...
# 2  this modified version of 'mom's' chili was a h...
# 3  this is a super easy, great tasting, make ahea...
# 4  my dh's amish mother raised him on this recipe...
#
#                                          ingredients  n_ingredients
# 0  ['winter squash', 'mexican seasoning', 'mixed ...              7
# 1  ['prepared pizza crust', 'sausage patty', 'egg...              6
# 2  ['ground beef', 'yellow onions', 'diced tomato...             13
# 3  ['spreadable cheese with garlic and herbs', 'n...             11
# 4  ['tomato juice', 'apple cider vinegar', 'sugar...              8

# %%
df.describe()
# Out:
#                   id       minutes  contributor_id        n_steps  \
# count  231637.000000  2.316370e+05    2.316370e+05  231637.000000
# mean   222014.708984  9.398546e+03    5.534885e+06       9.765499
# std    141206.635626  4.461963e+06    9.979141e+07       5.995128
# min        38.000000  0.000000e+00    2.700000e+01       0.000000
# 25%     99944.000000  2.000000e+01    5.690500e+04       6.000000
# 50%    207249.000000  4.000000e+01    1.736140e+05       9.000000
# 75%    333816.000000  6.500000e+01    3.982750e+05      12.000000
# max    537716.000000  2.147484e+09    2.002290e+09     145.000000
#
#        n_ingredients
# count  231637.000000
# mean        9.051153
# std         3.734796
# min         1.000000
# 25%         6.000000
# 50%         9.000000
# 75%        11.000000
# max        43.000000

# %%
ingredients_df = df[["id", "ingredients"]]
ingredients_df.head()
# Out:
#        id                                        ingredients
# 0  137739  ['winter squash', 'mexican seasoning', 'mixed ...
# 1   31490  ['prepared pizza crust', 'sausage patty', 'egg...
# 2  112140  ['ground beef', 'yellow onions', 'diced tomato...
# 3   59389  ['spreadable cheese with garlic and herbs', 'n...
# 4   44061  ['tomato juice', 'apple cider vinegar', 'sugar...

# %%
from ast import literal_eval
# Convert to list so explode works
ingredients_df["ingredients"] = ingredients_df["ingredients"].apply(literal_eval)

ingredients_df = ingredients_df.explode("ingredients", ignore_index=True)
ingredients_df.head()
# Out:
# /tmp/ipykernel_619/3679028598.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   ingredients_df["ingredients"] = ingredients_df["ingredients"].apply(literal_eval)
#        id        ingredients
# 0  137739      winter squash
# 1  137739  mexican seasoning
# 2  137739        mixed spice
# 3  137739              honey
# 4  137739             butter

# %%
unique_ingredients = pd.unique(ingredients_df["ingredients"])
len(unique_ingredients)
# Out:
# 14942

# %%
ingredient_counts = ingredients_df.groupby("ingredients").count()
ingredient_counts.describe()
# Out:
#                  id
# count  14942.000000
# mean     140.314683
# std     1341.349585
# min        1.000000
# 25%        2.000000
# 50%        5.000000
# 75%       28.000000
# max    85746.000000

# %%
ingredient_counts.sort_values("id", ascending=False)[:25]
# Out:
#                       id
# ingredients
# salt               85746
# butter             54975
# sugar              44535
# onion              39065
# water              34914
# eggs               33761
# olive oil          32822
# flour              26266
# milk               25786
# garlic cloves      25748
# pepper             22319
# brown sugar        18655
# garlic             18087
# all-purpose flour  17659
# baking powder      17504
# egg                17304
# salt and pepper    15415
# parmesan cheese    14807
# lemon juice        14233
# baking soda        14099
# vegetable oil      13912
# vanilla            13315
# black pepper       13098
# cinnamon           12560
# tomatoes           11950

# %%
ingredient_counts.sort_values("id", ascending=False)[-25:]
# Out:
#                                             id
# ingredients
# low-fat double cream                         1
# low-fat cream of potato soup                 1
# low-fat pizza sauce                          1
# low-fat saltine crackers                     1
# low-sodium italian salad dressing            1
# low-fat white cheddar cheese                 1
# low-sodium hot sauce                         1
# low-sodium cheddar cheese                    1
# low-sodium bouillon cube                     1
# low-sodium barbecue sauce                    1
# low-salt ham                                 1
# low-fat whole wheat tortilla                 1
# low-fat whole grain waffles                  1
# low-fat whole grain waffle                   1
# low-fat whipped cream                        1
# low-fat soft cheese                          1
# low-fat waffles                              1
# low-fat vanilla pudding                      1
# low-fat tzatziki                             1
# low-fat tropical yogurt                      1
# low-fat tomato soup                          1
# low-fat sugar-free frozen vanilla yogurt     1
# low-fat spicy chicken sausage                1
# low-fat soft cheese with chives and onions   1
# zwieback toast crumbs                        1

# %%
sbn.boxplot(ingredient_counts)
# Out:
# /root/.cache/pypoetry/virtualenvs/recipe-finder-VsnhxLU2-py3.9/lib/python3.9/site-packages/seaborn/categorical.py:470: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_data = [np.asarray(s, float) for k, s in iter_data]
# <AxesSubplot: >

# %%
ingredient_counts[ingredient_counts.index.str.contains("pepper")].sort_values("id", ascending=False)[:50]
# Out:
#                                        id
# ingredients
# pepper                              22319
# salt and pepper                     15415
# black pepper                        13098
# fresh ground black pepper            7160
# cayenne pepper                       6285
# red bell pepper                      4450
# green pepper                         4301
# ground black pepper                  3936
# green bell pepper                    3287
# fresh ground pepper                  3220
# salt & freshly ground black pepper   3123
# crushed red pepper flakes            2936
# white pepper                         2837
# red pepper flakes                    2602
# red pepper                           2252
# salt & pepper                        2156
# bell pepper                          1506
# jalapeno pepper                      1333
# hot pepper sauce                     1228
# ground pepper                        1078
# red bell peppers                     1015
# ground red pepper                     946
# green peppers                         899
# salt and black pepper                 898
# jalapeno peppers                      848
# cracked black pepper                  810
# fresh coarse ground black pepper      790
# black peppercorns                     749
# yellow bell pepper                    687
# pepperoni                             677
# sweet red pepper                      668
# bell peppers                          668
# green bell peppers                    630
# lemon pepper                          615
# monterey jack pepper cheese           531
# red peppers                           526
# roasted red peppers                   511
# roasted red pepper                    500
# salt & fresh ground pepper            452
# ground cayenne pepper                 415
# yellow pepper                         366
# peppercorns                           366
# red chili pepper                      254
# peppermint extract                    250
# chili pepper                          233
# green chili peppers                   230
# peppercorn                            216
# dried chili pepper flakes             210
# cracked pepper                        207
# red chili pepper flakes               204

# %%
ingredient_counts[ingredient_counts.index.str.contains("salt")].sort_values("id", ascending=False)[:50]
# Out:
#                                               id
# ingredients
# salt                                       85746
# salt and pepper                            15415
# unsalted butter                             8935
# kosher salt                                 5583
# sea salt                                    3138
# salt & freshly ground black pepper          3123
# garlic salt                                 2636
# seasoning salt                              2261
# salt & pepper                               2156
# coarse salt                                 1095
# salt and black pepper                        898
# celery salt                                  820
# table salt                                   558
# salt & fresh ground pepper                   452
# onion salt                                   442
# salted butter                                380
# saltine crackers                             299
# salted peanuts                               276
# lawry's seasoned salt                        195
# coarse sea salt                              189
# fine sea salt                                180
# kosher salt & freshly ground black pepper    170
# season salt                                  170
# pickling salt                                130
# unsalted peanuts                             118
# salt pork                                    110
# salted cashews                                90
# sweet unsalted butter                         78
# unsalted dry roasted peanuts                  73
# fine salt                                     72
# unsalted cashews                              71
# canning salt                                  70
# flaked sea salt                               61
# no-salt-added diced tomatoes                  59
# rock salt                                     57
# no-salt-added tomato sauce                    56
# salt substitute                               55
# season-all salt                               53
# dry roasted salted peanut                     48
# salt water                                    47
# unsalted margarine                            43
# unsalted sunflower seeds                      41
# saltines                                      38
# dry-roasted unsalted peanuts                  35
# unsalted chicken stock                        35
# saltine                                       35
# roasted unsalted peanuts                      34
# no-added-salt tomato paste                    33
# saltine crumbs                                33
# salt cod fish                                 27

# %%
ingredient_counts[ingredient_counts.index.str.contains("salt")].sort_values("id", ascending=False)[:50]
# Out:
#                                               id
# ingredients
# salt                                       85746
# salt and pepper                            15415
# unsalted butter                             8935
# kosher salt                                 5583
# sea salt                                    3138
# salt & freshly ground black pepper          3123
# garlic salt                                 2636
# seasoning salt                              2261
# salt & pepper                               2156
# coarse salt                                 1095
# salt and black pepper                        898
# celery salt                                  820
# table salt                                   558
# salt & fresh ground pepper                   452
# onion salt                                   442
# salted butter                                380
# saltine crackers                             299
# salted peanuts                               276
# lawry's seasoned salt                        195
# coarse sea salt                              189
# fine sea salt                                180
# kosher salt & freshly ground black pepper    170
# season salt                                  170
# pickling salt                                130
# unsalted peanuts                             118
# salt pork                                    110
# salted cashews                                90
# sweet unsalted butter                         78
# unsalted dry roasted peanuts                  73
# fine salt                                     72
# unsalted cashews                              71
# canning salt                                  70
# flaked sea salt                               61
# no-salt-added diced tomatoes                  59
# rock salt                                     57
# no-salt-added tomato sauce                    56
# salt substitute                               55
# season-all salt                               53
# dry roasted salted peanut                     48
# salt water                                    47
# unsalted margarine                            43
# unsalted sunflower seeds                      41
# saltines                                      38
# dry-roasted unsalted peanuts                  35
# unsalted chicken stock                        35
# saltine                                       35
# roasted unsalted peanuts                      34
# no-added-salt tomato paste                    33
# saltine crumbs                                33
# salt cod fish                                 27

# %%
items = ['green pepper', 'black beans', 'cheddar cheese', 'salmon']

# %%
matching_items = ingredients_df[ingredients_df["ingredients"].isin(items)].groupby("id").count().sort_values("ingredients", ascending=False)

# %%
matching_items.head()
# Out:
#         ingredients
# id
# 105280            3
# 250676            3
# 240689            3
# 141940            3
# 115196            3

# %%
joined_df = df.join(matching_items, on='id', lsuffix='_left', how='inner')

# %%
joined_df.head()
# Out:
#                                      name      id  minutes  contributor_id  \
# 2               all in the kitchen  chili  112140      130          196586
# 26            fool the meat eaters  chili   54272       40           40525
# 29  george s at the cove  black bean soup   44123       90           35193
# 31         global gourmet  taco casserole   59952       55           28604
# 46                   italian  gut busters   35173       45           22724
#
#      submitted                                               tags  \
# 2   2005-02-25  ['time-to-make', 'course', 'preparation', 'mai...
# 26  2003-02-17  ['60-minutes-or-less', 'time-to-make', 'course...
# 29  2002-10-25  ['weeknight', 'time-to-make', 'course', 'main-...
# 31  2003-04-16  ['60-minutes-or-less', 'time-to-make', 'course...
# 46  2002-07-27  ['60-minutes-or-less', 'time-to-make', 'course...
#
#                                         nutrition  n_steps  \
# 2      [269.8, 22.0, 32.0, 48.0, 39.0, 27.0, 5.0]        6
# 26      [295.6, 3.0, 56.0, 76.0, 32.0, 1.0, 18.0]        9
# 29  [804.7, 108.0, 26.0, 19.0, 28.0, 214.0, 10.0]       11
# 31     [456.8, 40.0, 34.0, 67.0, 57.0, 51.0, 9.0]       11
# 46   [816.9, 100.0, 11.0, 97.0, 98.0, 180.0, 2.0]        7
#
#                                                 steps  \
# 2   ['brown ground beef in large pot', 'add choppe...
# 26  ['rehydrate tvp if needed', 'spray or oil a la...
# 29  ['in 1 / 4 cup butter , saute carrots , onion ...
# 31  ['heat oven to 375 degrees', 'brown ground bee...
# 46  ['lay out sandwich rolls on jelly roll pans / ...
#
#                                           description  \
# 2   this modified version of 'mom's' chili was a h...
# 26  this recipe was adapted by my mother and mysel...
# 29  an original recipe created by chef scott meska...
# 31  hey! i found this in a cookbook that recognize...
# 46  my sister-in-law made these for us at a family...
#
#                                      ingredients_left  n_ingredients  \
# 2   ['ground beef', 'yellow onions', 'diced tomato...             13
# 26  ['vegetarian ground beef', 'garlic', 'onion', ...             12
# 29  ['unsalted butter', 'carrot', 'onion', 'celery...             18
# 31  ['ground beef', 'onion', 'tomato sauce', 'taco...             12
# 46  ['sandwich bun', 'good seasonings italian sala...              9
#
#     ingredients
# 2             1
# 26            1
# 29            1
# 31            1
# 46            1
